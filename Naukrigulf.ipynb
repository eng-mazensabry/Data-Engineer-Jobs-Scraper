# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
 
options = Options()
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
##options.add_argument("--headless=new")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
 
 
driver = webdriver.Chrome(options=options)
url =('https://www.naukrigulf.com/')
driver.get(url)
time.sleep(2)

driver.find_element(By.XPATH,"//button[@type='button']").click()
driver.find_element(By.XPATH, "//input[@id='qsbKey']").send_keys('Data Engineer')
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, "input[value='Search Jobs']").click()
time.sleep(5)
driver.refresh()
time.sleep(2)

list_jobs = []
for page in range (3):
   print (page+1)

jobs = driver.find_elements(By.CSS_SELECTOR, "div.srp-tuple")
for job in jobs:
        job_title = job.find_element(By.CLASS_NAME, "designation-title").text
        job_company = job.find_element(By.CLASS_NAME, 'info-org').text
        job_location = job.find_element(By.CLASS_NAME, 'info-loc ').text
        job_link = job.find_element(By.CLASS_NAME, "info-org").get_attribute('href')
        job_experience = job.find_element(By.CLASS_NAME, 'info-exp').text
        job_description = job.find_element(By.CLASS_NAME, 'description').text
        list_jobs.append(
            {
            'Job Title': job_title,
            'Company': job_company,
            'Location': job_location,
            'Link': job_link,
            'Experience': job_experience,
            'Description': job_description
        }
        )
driver.find_element(By.XPATH, "//span[@class='ico bwd']").click()
time.sleep(5)
df = pd.DataFrame(list_jobs)
df.to_csv('Naukrigulf_jobs.csv', index=False)
# Out:
# 1
# 2
# 3

# %%
df
# Out:
#                                             Job Title  \
# 0                                DATA ENGINEER – (DX)
# 1                                       Data Engineer
# 2                          Applied AI & Data Engineer
# 3                               FinTech Data Engineer
# 4                                       Data Engineer
# 5                                       Data Engineer
# 6               Senior Data Engineer (Arabic Speaker)
# 7                                  Data Engineer/Test
# 8                                       Data Engineer
# 9                        Senior Data Engineer (Spark)
# 10               Senior Consultant - Data Engineering
# 11  Manager - Model Implementation, Data Engineeri...
# 12                                      Data Engineer
# 13                            Snowflake Data Engineer
# 14                            Snowflake Data Engineer
# 15                                      Data Engineer
# ...
